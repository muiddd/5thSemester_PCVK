# %% [markdown]
# <a href="https://colab.research.google.com/github/muiddd/5thSemester_PCVK/blob/main/TugasKelompok_Modul1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Kelompok 3**
#
# Anggota :
#
# *   Abdul Muid(244107020006)
# *   Fajar Eka Sandiyuda (244107020043)
# *   Qruzeeta Prasna Umeri Al Jawy(244107020084)
#
#
#
# Tugas :
# Melakukan sensor pada foto KTM bagian tulisan POLITEKNIK NEGERI MALANG, BNI dan
# Prodi

# %% [markdown]
# ##**1. Import Librarry**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# ##**2. Upload file**

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fa3aa85d-6fd9-4a51-98b1-2e25c7648d63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa3aa85d-6fd9-4a51-98b1-2e25c7648d63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ##**3. Menampilkan Citra KTM**

# %%
FILE_KTM = "KTM.jpeg"
img = cv.imread(FILE_KTM)
cv2_imshow(img)

imgRGB = cv.cvtColor(img, cv.COLOR_BGR2RGB)  # Konversi BGR ke RGB
plt.imshow(imgRGB)
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1007>

# %% [markdown]
# ##**4. Menutup Bagian Tertentu pada KTM**

# %%
img_tertutup = img.copy()

# AREA 1: Tutup tulisan "POLITEKNIK NEGERI MALANG" (RED)
pt1_1, pt2_1 = (180, 50), (600, 160)
warna_1 = (0, 0, 255) # Merah
cv.rectangle(img_tertutup, pt1=pt1_1, pt2=pt2_1, color=warna_1, thickness=-1)

# AREA 2 : Bagian Bank BNI (GREEN)
pt1_2, pt2_2 = (1050, 50), (1450, 160)
warna_2 = (0, 255, 0) # Hijau
cv.rectangle(img_tertutup, pt1=pt1_2, pt2=pt2_2, color=warna_2, thickness=-1)

# AREA 3 : Bagian Prodi (BLUE)
pt1_3, pt2_3 = (350, 900), (850, 970)
warna_3 = (255, 0, 0) # Biru
cv.rectangle(img_tertutup, pt1=pt1_3, pt2=pt2_3, color=warna_3, thickness=-1)

# Tampilkan hasil
imgRGB_tertutup = cv.cvtColor(img_tertutup, cv.COLOR_BGR2RGB)
plt.imshow(imgRGB_tertutup)
plt.title("KTM setelah bagian tertentu ditutup")
plt.show()

# %%
img_coba = imgRGB_tertutup.copy()

plt.imshow(img_coba)
plt.xticks(range(0, img_coba.shape[1], 50))
plt.yticks(range(0, img_coba.shape[0], 50))
plt.show()
